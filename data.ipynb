# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.3 MB 7.5 MB/s eta 0:00:02
#    ------------ --------------------------- 3.7/11.3 MB 9.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.3 MB 10.5 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.3 MB 11.0 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.3 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 10.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ZAID\OneDrive\Documents\3eme_gds\DL\DeepLearning_1\analyse_psychologique\outputs\analyse_complete_CLEAN.csv")
df.head()
# Out:
#     id_cas       modele  sample_id categorie_cas verdict_scientifique  \
# 0  CAS_001  gpt_oss_20b        1.0     Anxiogène              prouvee
# 1  CAS_002  gpt_oss_20b        1.0        Simple            plausible
# 2  CAS_003  gpt_oss_20b        1.0      Complexe            plausible
# 3  CAS_004  gpt_oss_20b        1.0     Anxiogène              prouvee
# 4  CAS_005  gpt_oss_20b        1.0      Complexe            plausible
#
#                                        justification  \
# 0  La réponse fournie est clairement soutenue par...
# 1  La réponse fournit des conseils généraux et de...
# 2  La réponse fournie est globalement cohérente e...
# 3  La réponse fournie est clairement soutenue par...
# 4  La réponse fournie est globalement cohérente a...
#
#                                    sources_utilisees  topk  batch_start  \
# 0  has:#chunk=6 | has:#chunk=235 | has:#chunk=33 ...   6.0          1.0
# 1  has:#chunk=6 | has:#chunk=92 | has:#chunk=35 |...   6.0          1.0
# ...

# %%
df.columns
# Out:
# Index(['id_cas', 'modele', 'sample_id', 'categorie_cas',
#        'verdict_scientifique', 'justification', 'sources_utilisees', 'topk',
#        'batch_start', 'batch_end', 'timestamp_eval', 'ton_rassurant',
#        'ton_alarmiste', 'ton_neutre', 'ton_dominant', 'anxiete_induite',
#        'niveau_anxiete', 'score_certitude', 'score_incertitude',
#        'score_autorite', 'credibilite_percue', 'niveau_credibilite',
#        'risque_influence', 'niveau_risque', 'score_empathie',
#        'score_reassurance', 'empathie_globale', 'niveau_empathie',
#        'impact_psychologique_global'],
#       dtype='object')

# %%
df1 = pd.read_csv(
    r"C:\Users\ZAID\OneDrive\Documents\3eme_gds\DL\DeepLearning_1\generation\reponses\reponses_llms_structured.csv"
)

# %%
df1.columns
# Out:
# Index(['﻿id_cas', 'categorie_cas', 'modele', 'sample_id', 'prompt',
#        'reponse_modele', 'timestamp'],
#       dtype='object')

# %%
df2 = pd.read_csv(
    r"C:\Users\ZAID\OneDrive\Documents\3eme_gds\DL\DeepLearning_1\dataset\data\cas_cliniques.csv"
)

# %%
df2.columns
# Out:
# Index(['id', 'titre', 'description', 'categorie', 'objectif'], dtype='object')

# %%
df5 = pd.read_csv(
    r"C:\Users\ZAID\OneDrive\Documents\3eme_gds\DL\DeepLearning_1\dataset_complet.csv"
)

# %%
df5.columns
# Out:
# Index(['id_cas', 'titre', 'description', 'categorie', 'objectif',
#        'categorie_cas', 'modele', 'sample_id', 'prompt', 'reponse_texte',
#        'timestamp', 'verdict_scientifique', 'justification',
#        'sources_utilisees', 'topk', 'batch_start', 'batch_end',
#        'ton_rassurant', 'ton_alarmiste', 'ton_neutre', 'ton_dominant',
#        'anxiete_induite', 'niveau_anxiete', 'score_certitude',
#        'score_incertitude', 'score_autorite', 'credibilite_percue',
#        'niveau_credibilite', 'risque_influence', 'niveau_risque',
#        'score_empathie', 'score_reassurance', 'empathie_globale',
#        'niveau_empathie', 'impact_psychologique_global', 'longueur_reponse',
#        'nb_mots'],
#       dtype='object')
